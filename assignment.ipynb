# %% [markdown]
# # Assignment 7: Data Visualization
#
# ## Overview
# This assignment covers the essential tools for data visualization: matplotlib fundamentals, seaborn statistical plots, pandas plotting, and visualization best practices.
#
# ## Setup

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# Set style
plt.style.use('default')
sns.set_style('whitegrid')

# Create output directory
os.makedirs('output', exist_ok=True)

# %% [markdown]
# ## Question 1: matplotlib Fundamentals
#
# ### Part 1.1: Basic Figures and Subplots
#
# **TODO: Create a figure with 2x2 subplots showing different plot types**

# %%
# Create sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(-x/5)
y4 = np.log(x + 1)

# TODO: Create a 2x2 subplot grid
# TODO: Add titles and labels to each subplot
# TODO: Add grid to each subplot
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# TODO: Plot on each subplot
# Top-left: Sine wave
axes[0, 0].plot(x, y1, color = 'blue', linewidth = 2)
axes[0, 0].set_title('Sine Wave')
axes[0, 0].set_xlabel('x')
axes[0, 0].set_ylabel('sin(x)')
axes[0, 0].grid(True)

# Top-right: Cosine wave  
axes[0, 1].plot(x, y2, color = 'red', linewidth =2)
axes[0, 1].set_title('Cosine Wave')
axes[0, 1].set_xlabel('x')
axes[0, 1].set_ylabel('cos(x)')
axes[0, 1].grid(True)

# Bottom-left: Exponential decay
axes[1, 0].plot(x, y3, color = 'green', linewidth = 2)
axes[1, 0].set_title('Exponential Decay')
axes[1, 0].set_xlabel('x')
axes[1, 0].set_ylabel('exp(-x/5)')
axes[1, 0].grid(True)

# Bottom-right: Logarithmic function
axes[1, 1].plot(x, y4, color = 'magenta', linewidth =2)
axes[1, 1].set_title('Logarithmic Function')
axes[1, 1].set_xlabel('x')
axes[1, 1].set_ylabel('log(x+1)')
axes[1, 1].grid(True)


# TODO: Use tight_layout() to prevent overlapping
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part 1.2: Plot Customization
#
# **TODO: Create a customized line plot with multiple series**

# %%
# Create sample data
x = np.linspace(0, 10, 50)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)

# TODO: Create a figure with custom styling
fig, ax = plt.subplots(figsize=(10, 6))

# TODO: Plot three lines with different styles
# Line 1: Solid line, blue color, label 'sin(x)'
# Line 2: Dashed line, red color, label 'cos(x)'  
# Line 3: Dotted line, green color, label 'sin(x)*cos(x)'
ax.plot(x, y1, linestyle = '-', color = 'blue', linewidth = 2, label = 'sin(x)')
ax.plot(x, y2, linestyle = '--', color = 'red', linewidth = 2, label = 'cos(x)')
ax.plot(x, y3, linestyle = ':', color = 'green', linewidth = 2, label = 'sin(x)*cos(x)')

# TODO: Add title, xlabel, ylabel
ax.set_title('Trigonometric Functions', fontsize = 16, fontweight = 'bold')
ax.set_xlabel('x', fontsize = 12)
ax.set_ylabel('y', fontsize = 12)

# TODO: Add legend
ax.legend(loc = 'upper right', fontsize = 10)

# TODO: Add grid with transparency
ax.grid(True, alpha = 0.3)

# TODO: Set appropriate axis limits
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)

plt.show()

# %% [markdown]
# ### Part 1.3: Different Plot Types
#
# **TODO: Create a comprehensive visualization with multiple plot types**

# %%
# Create sample data
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 56, 12, 78]
x_scatter = np.random.randn(100)
y_scatter = 2 * x_scatter + np.random.randn(100)
hist_data = np.random.normal(0, 1, 1000)

# TODO: Create a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Bar chart
axes[0, 0].bar(categories, values, color = ['blue', 'red', 'orange', 'purple'], 
               edgecolor = 'black', linewidth = 1.5)
axes[0, 0].set_title('Bar Chart', fontsize = 14, fontweight = 'bold')
axes[0, 0].set_xlabel('Categories', fontsize = 12)
axes[0, 0].set_ylabel('Values', fontsize = 12)
axes[0, 0].grid(True, alpha = 0.3, axis = 'y')

# TODO: Top-right: Scatter plot
axes[0, 1].scatter(x_scatter, y_scatter, c = 'blue', alpha = 0.6,
                   edgecolors = 'black', linewidth = 0.5, s= 50)
axes[0, 1].set_title('Scatter Plot', fontsize = 14, fontweight = 'bold')
axes[0, 1].set_xlabel('x-values', fontsize = 12)
axes[0, 1].set_ylabel('y-values', fontsize = 12)
axes[0, 1].grid(True, alpha = 0.3)

# TODO: Bottom-left: Histogram
axes[1, 0].hist(hist_data, bins = 30, color = 'teal', alpha = 0.7, 
                edgecolor = 'black', linewidth = 1)
axes[1, 0].set_title('Histogram', fontsize = 14, fontweight = 'bold')
axes[1, 0].set_xlabel('Values', fontsize = 12)
axes[1, 0].set_ylabel('Frequency', fontsize = 12)
axes[1, 0].grid(True, alpha = 0.3, axis = 'y')

# TODO: Bottom-right: Pie chart
colors_pie = ['gold', 'lightblue', 'lightcoral', 'lightskyblue', 'lightgreen']
axes[1, 1].pie(values, labels = categories, colors = colors_pie, autopct = '%1.1f%%',
               startangle = 90, wedgeprops = {'edgecolor': 'black', 'linewidth': 1.5})
axes[1, 1].set_title('Pie Chart', fontsize = 14, fontweight='bold')

# TODO: Add appropriate titles and labels
# TODO: Customize colors and styles
# TODO: Save the plot as 'output/q1_matplotlib_plots.png'

plt.tight_layout()
plt.savefig('output/q1_matplotlib_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Question 2: seaborn Statistical Visualization
#
# ### Part 2.1: Load and Explore Data

# %%
# Load the sales data
sales_df = pd.read_csv('data/sales_data.csv')
customer_df = pd.read_csv('data/customer_data.csv')
product_df = pd.read_csv('data/product_data.csv')

# Merge data for analysis
merged_df = sales_df.merge(customer_df, on='customer_id').merge(product_df, on='product_id')

print("Data shape:", merged_df.shape)
print("\nColumns:", merged_df.columns.tolist())
print("\nFirst few rows:")
print(merged_df.head())
# Out:
# Data shape: (1000, 19)
#
# Columns: ['transaction_id', 'customer_id', 'product_id', 'quantity', 'unit_price_x', 'total_amount', 'transaction_date', 'store_location', 'customer_name', 'age', 'gender', 'city', 'state', 'registration_date', 'product_name', 'category', 'brand', 'unit_price_y', 'stock_quantity']
#
# First few rows:
#   transaction_id customer_id product_id  quantity  unit_price_x  total_amount  \
# 0          T0001       C0103       P040        10    229.359978   2293.599785
# 1          T0002       C0180       P083         3     75.794677    227.384031
# 2          T0003       C0093       P042         5    479.387719   2396.938597
# 3          T0004       C0015       P041         5    269.533265   1347.666324
# 4          T0005       C0107       P006         4    128.527714    514.110856
#
#   transaction_date store_location customer_name  age gender         city  \
# 0       2025-10-14          South  Customer 103   23      F       Dallas
# 1       2025-07-26          North  Customer 180   45      M       Dallas
# 2       2025-06-30           East   Customer 93   70      M  Los Angeles
# 3       2025-08-01          South   Customer 15   35      F  San Antonio
# 4       2025-08-07          South  Customer 107   39      F      Houston
#
#   state registration_date product_name       category    brand  unit_price_y  \
# 0    IL        2025-07-31   Product 40       Clothing  Brand E    230.048472
# 1    TX        2025-07-08   Product 83          Books  Brand C    385.510134
# 2    OH        2025-09-30   Product 42    Electronics  Brand C    289.744456
# 3    CA        2025-09-04   Product 41  Home & Garden  Brand A    293.030410
# 4    NC        2025-07-09    Product 6       Clothing  Brand B    242.636813
#
#    stock_quantity
# 0              52
# 1              78
# 2              70
# 3              32
# 4              39

# %% [markdown]
# ### Part 2.2: Statistical Plots
#
# **TODO: Create statistical visualizations with seaborn**

# %%
# TODO: Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Box plot of total_amount by store_location
sns.boxplot(data = merged_df, x = 'store_location', y = 'total_amount', 
            palette = 'Set2', ax = axes[0, 0])
axes[0, 0].set_title('Total Amount by Store Location', fontsize = 14, fontweight ='bold')
axes[0, 0].set_xlabel('Store Location', fontsize = 12)
axes[0, 0].set_ylabel('Total Amount ($)', fontsize = 12)
axes[0, 0].grid(True, alpha = 0.3, axis = 'y')

# TODO: Top-right: Violin plot of total_amount by category
sns.violinplot(data = merged_df, x = 'category', y = 'total_amount', 
               palette = 'muted', ax = axes[0, 1])
axes[0, 1].set_title('Total Amount Distribution by Category', fontsize = 14, fontweight = 'bold')
axes[0, 1].set_xlabel('Category', fontsize = 12)
axes[0, 1].set_ylabel('Total Amount ($)', fontsize = 12)
axes[0, 1].tick_params(axis = 'x', rotation = 45)
axes[0, 1].grid(True, alpha = 0.3, axis = 'y')

# TODO: Bottom-left: Scatter plot of quantity vs total_amount with hue by gender
sns.scatterplot(data = merged_df, x = 'quantity', y = 'total_amount', 
                hue='gender', palette = 'viridis', alpha = 0.6, s = 80, ax = axes[1, 0])
axes[1, 0].set_title('Quantity vs Total Amount by Gender', fontsize = 14, fontweight = 'bold')
axes[1, 0].set_xlabel('Quantity', fontsize = 12)
axes[1, 0].set_ylabel('Total Amount ($)', fontsize = 12)
axes[1, 0].legend(title = 'Gender', fontsize = 10)
axes[1, 0].grid(True, alpha = 0.3)

# TODO: Bottom-right: Histogram of total_amount with kde overlay
sns.histplot(data = merged_df, x = 'total_amount', bins = 30, kde = True, 
             color = 'skyblue', edgecolor = 'black', linewidth = 1, ax = axes[1, 1])
axes[1, 1].set_title('Distribution of Total Amount', fontsize = 14, fontweight = 'bold')
axes[1, 1].set_xlabel('Total Amount ($)', fontsize = 12)
axes[1, 1].set_ylabel('Frequency', fontsize = 12)
axes[1, 1].grid(True, alpha = 0.3, axis = 'y')

# TODO: Add appropriate titles and labels
# TODO: Customize colors and styling
# TODO: Save the plot as 'output/q2_seaborn_plots.png'

plt.tight_layout()
plt.savefig('output/q2_seaborn_plots.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/lk/cfqjvsz57sbbg9szxbdn30jc0000gn/T/ipykernel_77157/2604069899.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = merged_df, x = 'store_location', y = 'total_amount',
# /var/folders/lk/cfqjvsz57sbbg9szxbdn30jc0000gn/T/ipykernel_77157/2604069899.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = merged_df, x = 'category', y = 'total_amount',

# %% [markdown]
# ### Part 2.3: Correlation Analysis
#
# **TODO: Create a correlation heatmap**

# %%
# TODO: Select numeric columns for correlation analysis
# First, explore the merged data to see what columns are available
print("Available columns:", merged_df.columns.tolist())
print("Data types:")
print(merged_df.dtypes)

# TODO: Select only the numeric columns that exist for correlation analysis
# Hint: After merging, pandas adds _x and _y suffixes to duplicate column names
numeric_cols = merged_df.select_dtypes(include=[np.number]).columns.tolist()
print("\nNumeric columns found:", numeric_cols)

# TODO: Calculate correlation matrix
# correlation_matrix = ...
correlation_matrix = merged_df[numeric_cols].corr()

# TODO: Create heatmap with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, 
            annot=True,              
            fmt='.2f',               
            cmap='coolwarm',         
            center=0,                
            square=True,             
            linewidths=1,            
            cbar_kws={'shrink': 0.8},
            
            vmin=-1, vmax=1)  

# TODO: Add title and customize appearance
plt.title('Correlation Matrix of Numeric Variables', fontsize = 16, fontweight = 'bold', pad = 20)

# TODO: Save the plot as 'output/q2_correlation_heatmap.png'

plt.tight_layout()
plt.savefig('output/q2_correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Available columns: ['transaction_id', 'customer_id', 'product_id', 'quantity', 'unit_price_x', 'total_amount', 'transaction_date', 'store_location', 'customer_name', 'age', 'gender', 'city', 'state', 'registration_date', 'product_name', 'category', 'brand', 'unit_price_y', 'stock_quantity']
# Data types:
# transaction_id        object
# customer_id           object
# product_id            object
# quantity               int64
# unit_price_x         float64
# total_amount         float64
# transaction_date      object
# store_location        object
# customer_name         object
# age                    int64
# gender                object
# city                  object
# state                 object
# registration_date     object
# product_name          object
# category              object
# brand                 object
# unit_price_y         float64
# stock_quantity         int64
# dtype: object
#
# Numeric columns found: ['quantity', 'unit_price_x', 'total_amount', 'age', 'unit_price_y', 'stock_quantity']

# %% [markdown]
# ## Question 3: pandas Plotting and Data Exploration
#
# ### Part 3.1: Time Series Visualization
#
# **TODO: Create time series plots with pandas**

# %%
# TODO: Convert transaction_date to datetime
# merged_df['transaction_date'] = pd.to_datetime(merged_df['transaction_date'])
merged_df['transaction_date'] = pd.to_datetime(merged_df['transaction_date'])

# TODO: Create daily sales aggregation
# daily_sales = merged_df.groupby('transaction_date')['total_amount'].sum()
daily_sales = merged_df.groupby('transaction_date')['total_amount'].sum()

# TODO: Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Line plot of daily sales
daily_sales.plot(ax = axes[0, 0], color = 'blue', linewidth = 2)
axes[0, 0].set_title('Daily Sales Over Time', fontsize = 14, fontweight = 'bold')
axes[0, 0].set_xlabel('Date', fontsize = 12)
axes[0, 0].set_ylabel('Total Sales ($)', fontsize = 12)
axes[0, 0].grid(True, alpha = 0.3)

# TODO: Top-right: Rolling 7-day average
rolling_avg = daily_sales.rolling(window = 7).mean()
rolling_avg.plot(ax = axes[0, 1], color = 'green', linewidth = 2)
axes[0, 1].set_title('7-Day Rolling Average of Sales', fontsize = 14, fontweight = 'bold')
axes[0, 1].set_xlabel('Date', fontsize = 12)
axes[0, 1].set_ylabel('Average Sales ($)', fontsize = 12)
axes[0, 1].grid(True, alpha = 0.3)

# TODO: Bottom-left: Monthly sales bar chart (use resample('ME') for month-end frequency)
monthly_sales = daily_sales.resample('ME').sum()
monthly_sales.plot(kind = 'bar', ax = axes[1, 0], color = 'gold', edgecolor = 'black', linewidth = 1)
axes[1, 0].set_title('Monthly Sales', fontsize = 14, fontweight = 'bold')
axes[1, 0].set_xlabel('MOnth', fontsize = 12)
axes[1, 0].set_ylabel('Total Sales ($)', fontsize = 12)
axes[1, 0].tick_params(axis = 'x', rotation = 45)
axes[1, 0].grid(True, alpha = 0.3, axis = 'y')

# TODO: Bottom-right: Sales distribution histogram
daily_sales.plot(kind = 'hist', bins = 30, ax = axes[1, 1], color = 'purple', 
                 edgecolor = 'black', linewidth = 1, alpha = 0.7)
axes[1, 1].set_title('Distribution of Daily Sales', fontsize = 14, fontweight='bold')
axes[1, 1].set_xlabel('Daily Sales ($)', fontsize = 12)
axes[1, 1].set_ylabel('Frequency', fontsize = 12)
axes[1, 1].grid(True, alpha = 0.3, axis = 'y')

# TODO: Add titles and labels
# TODO: Save the plot as 'output/q3_pandas_plots.png'

plt.tight_layout()
plt.savefig('output/q3_pandas_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Part 3.2: Data Overview Dashboard
#
# **TODO: Create a comprehensive data overview**

# %%
# TODO: Create a figure with multiple subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# TODO: Plot 1: Sales by category (bar chart)
category_sales = merged_df.groupby('category')['total_amount'].sum().sort_values(ascending = False)
category_sales.plot(kind ='bar', ax = axes[0, 0], color = 'steelblue', edgecolor = 'black', linewidth = 1.5)
axes[0, 0].set_title('Sales by Category', fontsize = 14, fontweight = 'bold')
axes[0, 0].set_xlabel('Category', fontsize = 12)
axes[0, 0].set_ylabel('Total Sales ($)', fontsize = 12)
axes[0, 0].tick_params(axis = 'x', rotation = 45)
axes[0, 0].grid(True, alpha = 0.3, axis = 'y')

# TODO: Plot 2: Sales by store location (pie chart)
store_sales = merged_df.groupby('store_location')['total_amount'].sum()
colors_pie = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen', 'plum']
axes[0, 1].pie(store_sales, labels = store_sales.index, autopct = '%1.1f%%', 
               colors = colors_pie, startangle = 90, 
               wedgeprops = {'edgecolor': 'black', 'linewidth': 1.5})
axes[0, 1].set_title('Sales by Store Location', fontsize = 14, fontweight = 'bold')

# TODO: Plot 3: Age distribution (histogram)
axes[0, 2].hist(merged_df['age'], bins = 20, color = 'green', alpha = 0.7, 
                edgecolor = 'black', linewidth = 1)
axes[0, 2].set_title('Customer Age Distribution', fontsize = 14, fontweight = 'bold')
axes[0, 2].set_xlabel('Age', fontsize = 12)
axes[0, 2].set_ylabel('Frequency', fontsize = 12)
axes[0, 2].grid(True, alpha = 0.3, axis = 'y')

# TODO: Plot 4: Quantity vs total_amount scatter
axes[1, 0].scatter(merged_df['quantity'], merged_df['total_amount'], 
                   alpha = 0.5, c = 'purple', s = 50, edgecolors = 'black', linewidth = 0.5)
axes[1, 0].set_title('Quantity vs Total Amount', fontsize = 14, fontweight = 'bold')
axes[1, 0].set_xlabel('Quantity', fontsize = 12)
axes[1, 0].set_ylabel('Total Amount ($)', fontsize = 12)
axes[1, 0].grid(True, alpha = 0.3)

# TODO: Plot 5: Sales over time (line plot)
daily_sales = merged_df.groupby('transaction_date')['total_amount'].sum()
daily_sales.plot(ax = axes[1, 1], color = 'darkblue', linewidth = 2)
axes[1, 1].set_title('Sales Over Time', fontsize = 14, fontweight = 'bold')
axes[1, 1].set_xlabel('Date', fontsize = 12)
axes[1, 1].set_ylabel('Total Sales ($)', fontsize = 12)
axes[1, 1].tick_params(axis = 'x', rotation = 45)
axes[1, 1].grid(True, alpha = 0.3)

# TODO: Plot 6: Top 10 products by sales (horizontal bar)
product_sales = merged_df.groupby('product_name')['total_amount'].sum().sort_values(ascending = True).tail(10)
product_sales.plot(kind = 'barh', ax = axes[1, 2], color = 'coral', edgecolor = 'black', linewidth = 1.5)
axes[1, 2].set_title('Top 10 Products by Sales', fontsize = 14, fontweight = 'bold')
axes[1, 2].set_xlabel('Total Sales ($)', fontsize = 12)
axes[1, 2].set_ylabel('Product Name', fontsize = 12)
axes[1, 2].grid(True, alpha = 0.3, axis = 'x')

# TODO: Add titles and customize appearance
plt.suptitle('Comprehensive Data Overview', fontsize = 18, fontweight = 'bold', y = 0.995)

# TODO: Save the plot as 'output/q3_data_overview.png'

plt.tight_layout()
plt.savefig('output/q3_data_overview.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, verify you've created:
#
# - [ ] `output/q1_matplotlib_plots.png` - matplotlib fundamentals
# - [ ] `output/q1_multi_panel.png` - multi-panel visualization
# - [ ] `output/q2_seaborn_plots.png` - seaborn statistical plots
# - [ ] `output/q2_correlation_heatmap.png` - correlation analysis
# - [ ] `output/q3_pandas_plots.png` - pandas plotting
# - [ ] `output/q3_data_overview.png` - data exploration
#
# ## Key Learning Objectives
#
# - Master matplotlib fundamentals for custom plots
# - Create statistical visualizations with seaborn
# - Use pandas plotting for quick exploration
# - Apply visualization best practices
# - Choose appropriate chart types for different data
